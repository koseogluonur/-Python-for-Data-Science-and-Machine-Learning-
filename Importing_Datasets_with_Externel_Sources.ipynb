# %% [markdown]
# <a href="https://colab.research.google.com/github/koseogluonur/-Python-for-Data-Science-and-Machine-Learning-/blob/main/Importing_Datasets_with_Externel_Sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pcden dosya yükleme
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5e1f32bf-c1b5-444d-89ed-6b258bc9d20d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e1f32bf-c1b5-444d-89ed-6b258bc9d20d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ornekcsv.csv to ornekcsv (1).csv
# {'ornekcsv.csv': b'a;b;c\n78;12;1\n78;12;2\n78;324;3\n7;2;4\n88;23;5\n6;2;\n56;11;6\n7;12;7\n56;21;7\n346;2;8\n5;1;8\n456;21;8\n3;12;88'}

# %%
#csv okuma
import pandas as pd
pd.read_csv("ornekcsv.csv",sep=";")
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
#txt okuma
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-12547294-5027-44e5-8792-7bf64163d338" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12547294-5027-44e5-8792-7bf64163d338">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving duz_metin.txt to duz_metin (1).txt
# {'duz_metin.txt': b'1 2\r2 2\r3 2\r4 2\r5 2\r6 2\r7 2 \r8 2\r9 2\r10 2\r'}

# %%
import pandas as pd
pd.read_csv("duz_metin.txt")
# Out:
#     1 2
# 0   2 2
# 1   3 2
# 2   4 2
# 3   5 2
# 4   6 2
# 5  7 2
# 6   8 2
# 7   9 2
# 8  10 2

# %%
#Excel okuma
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-35641267-7688-4136-891e-7fa3c3869ccd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35641267-7688-4136-891e-7fa3c3869ccd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ornekx.xlsx to ornekx (1).xlsx
# ...

# %%
pd.read_excel("ornekx.xlsx")
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
df=pd.read_excel("ornekx.xlsx")
df.head()
# Out:
#     a    b    c
# 0  78   12  1.0
# 1  78   12  2.0
# 2  78  324  3.0
# 3   7    2  4.0
# 4  88   23  5.0

# %%
#Githubdan tek bir dosyayı okutmak
#Kendi repondan veya başkasının reposundan istediğin dosyayı seçip rawa tıkla
#Ctrl A ile seçip ister txt ister excel dosyasına copy paste yap
#Ardından yükle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c11443e2-a2d1-42c5-b9f0-6d0fde4fc94d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c11443e2-a2d1-42c5-b9f0-6d0fde4fc94d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.txt to tips.txt
# ...

# %%
tips=pd.read_csv("tips.txt")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
#
# [205 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
